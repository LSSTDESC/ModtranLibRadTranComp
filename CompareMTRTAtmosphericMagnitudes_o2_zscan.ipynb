# %% [markdown]
# # Compare Modtran/libRadTran Magnitudes in I Filter and scan in airmass
#
# Scan in airmass
#
# - author : Sylvie Dagoret
# - affiliation : LAL/IN2P3/CNRS
# - creation date : November 5th 2018
# - update :

# %%
import pandas as pd
import numpy as np
import os,sys
from os import listdir
from os.path import isfile, join
import matplotlib.pyplot as plt
from astropy.io import fits
# %matplotlib inline
from scipy.interpolate import interp1d

# %%
from astropy.io import fits

# %%
from lsst.sims.photUtils import SignalToNoise
from lsst.sims.photUtils import PhotometricParameters
from lsst.sims.photUtils import Bandpass,Sed

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.colors as colors
import matplotlib.cm as cmx

# %%
# to enlarge the sizes
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (14, 8),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
plt.rcParams.update(params)

# %%
PATH_LIBRADTRAN='./librandtran'
PATH_MODTRAN='./modtran'
PATH_MYLSSTSIMS='./lsst_sims'

# %%
sys.path.append(PATH_LIBRADTRAN)
sys.path.append(PATH_MODTRAN)
sys.path.append(PATH_MYLSSTSIMS)

# %%
import libReadModtran as mt
import libsimulateTranspLSSTScattAbsAer3 as rt

# %%
from MyTelescope import *
from MyThroughputs import *

# %%
def plot_sedimg(data,index_spec):
    plt.figure(figsize=(15,10))   
    img=plt.imshow(data[1:,index_spec:],origin='lower',cmap='jet')
    plt.colorbar(img)
    plt.grid(True)
    plt.title('sed grid')
    plt.xlabel('bin number of wavelengths')
    plt.ylabel('sed number')
    plt.show()

# %%
def plot_allsed(data,index_spec):
    plt.figure()   
    
    for idx in np.arange(data.shape[0]-1):
      
        plt.semilogy(data[0,index_spec:],data[1+idx,index_spec:],'-')
    plt.grid(True)
    plt.title('sed')
    plt.xlabel('wavelength (A)')
    plt.ylabel('sed (flam)')
    plt.show()

# %% [markdown]
# # Config

# %%
#------------------------------------------------------------------------
# Definition of data format for the atmospheric grid
#-----------------------------------------------------------------------------
WLMIN=250.  # Minimum wavelength : PySynPhot works with Angstrom
WLMAX=1151. # Minimum wavelength : PySynPhot works with Angstrom
WL=np.arange(WLMIN,WLMAX,1) # Array of wavelength in Angstrom
NBWL=len(WL)

# %%
## Config LSST

# %%
all_filternum = {'u':1, 'g':2, 'r':3, 'i':4, 'z':5, 'y':6}

# %%
LSST_SkyBrightness=np.array([22.03,21.68,21.02,19.7,17.83,17.21])

# %%
LSST_GeomSeeing=np.array([1.1,1.02,0.95,0.92,0.88,0.94])

# %% [markdown]
# # Configuration of input SED

# %%
sed_file="regenerated_sedgrid_pickle_uvk.fits"

# %%
sed_hdu = fits.open(sed_file)

# %%
theheader=sed_hdu[0].header
theheader
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                  -64 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 8515
# NAXIS2  =                12963
# NBSED   =                12962
# NBWLBIN =                 8510
# WLMIN   =               3000.0
# WLMAX   =              11510.0
# WLBINWDT=                  1.0
# SEDUNIT = 'FLAM    '
# SEDMODEL= 'pickle_uvk'
# IDX_NUM =                    0
# IDX_VAL =                    1
# IDX_SED =                    2
# IDX_DATA=                    3
# IDX_SPEC=                    5

# %%
sidx_num=theheader['IDX_NUM']
sidx_val=theheader['IDX_VAL']
sidx_sed=theheader['IDX_SED']
sidx_data=theheader['IDX_DATA']
sidx_spec=theheader['IDX_SPEC']

# %%
sed_data=sed_hdu[0].data

# %%
plot_sedimg(sed_data,sidx_spec)

# %%
#plot_allsed(sed_data,sidx_spec)

# %%
NBSED_MAX=sed_data.shape[0]-1

# %%
NBSED_MAX
# Out:
# 12962

# %% [markdown]
# ## Config for Modtran

# %%
path_modtrandata='modtrandata/Jul6th2018'

# %%
def GetModtranFilenames():
    files_data = [f for f in listdir(path_modtrandata) if isfile(join(path_modtrandata, f))]
    files_data.sort()
    
    # select reduced files
    files_selected=[]
    for file in files_data:
        if file.find("_reduced")==-1:
            print("reject ",file)
        else:
            files_selected.append(file)
            
    files_selected.sort()
    return files_selected

# %%
def GetAirmassFromModtranFilename(filename):
    splitted_filename=filename.split('.')
    tagname=splitted_filename[1]
    airmass_str=tagname.split('_')[0]
    am=float(airmass_str)/10.
    return am

# %%
files_modtran=GetModtranFilenames()
# Out:
# reject  Pachon_MODTRAN.10.7sc
# reject  Pachon_MODTRAN.11.7sc
# reject  Pachon_MODTRAN.12.7sc
# reject  Pachon_MODTRAN.13.7sc
# reject  Pachon_MODTRAN.14.7sc
# reject  Pachon_MODTRAN.15.txt
# reject  Pachon_MODTRAN.16.7sc
# reject  Pachon_MODTRAN.17.7sc
# reject  Pachon_MODTRAN.18.7sc
# reject  Pachon_MODTRAN.19.7sc
# reject  Pachon_MODTRAN.20.7sc
# reject  Pachon_MODTRAN.21.7sc
# reject  Pachon_MODTRAN.22.7sc
# reject  Pachon_MODTRAN.23.7sc
# reject  Pachon_MODTRAN.25.7sc
# reject  Pachon_MODTRAN.7sc

# %%
NBMTFILES=len(files_modtran)-1

# %% [markdown]
# ### Get all all available Modtran Airmasss

# %%
all_airmasses=[GetAirmassFromModtranFilename(files_modtran[idx]) for idx in np.arange(NBMTFILES) ]

# %%
all_airmasses
# Out:
# [1.0, 1.1, 1.2, 1.3, 1.4, 1.6, 1.7, 1.8, 1.9, 2.0, 2.1, 2.2, 2.3, 2.5]

# %% [markdown]
# ### Read all Modtran Data

# %%
all_mtdata=[]
for file in files_modtran:
    fullfilename=os.path.join(path_modtrandata,file)
    read_modtrandata=mt.loadtape7(fullfilename, colspec = ['WAVELENGTH_NM','COMBIN_TRANS'])
    all_mtdata.append(read_modtrandata)

# %% [markdown]
# ### View all Modtran Data

# %%
jet = cm = plt.get_cmap('jet')
cNorm  = colors.Normalize(vmin=0, vmax=NBMTFILES)
scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=jet)

# %%
for idx in np.arange(NBMTFILES):    
    colorVal = scalarMap.to_rgba(idx)
    thelabel="z={:2.1f}".format(all_airmasses[idx])
    plt.plot(all_mtdata[idx][:,0],all_mtdata[idx][:,1],color=colorVal,label=thelabel)
plt.grid(True)
plt.title("MODTRAN 07/06/2018")
plt.xlabel("$\lambda$ (nm)")
plt.ylabel("atmospheric transparency")
plt.legend(loc='best')

# %%
all_airmasses
# Out:
# [1.0, 1.1, 1.2, 1.3, 1.4, 1.6, 1.7, 1.8, 1.9, 2.0, 2.1, 2.2, 2.3, 2.5]

# %% [markdown]
# # Select One Airmass for Modtran and One Filter where to do the Comparison

# %%
idx_am_sel=9

# %%
am_mt=all_airmasses[idx_am_sel]

# %%
print ("Modtran Airmass = ",am_mt)
# Out:
# Modtran Airmass =  2.0

# %%
mtdata_sel=all_mtdata[idx_am_sel]

# %% [markdown]
# Must extend Motran transmission up from 250 nm to 1151 nm

# %%
wl0=mtdata_sel[:,0]
tr0=mtdata_sel[:,1]

# %%
wl=np.copy(WL)
tr=np.ones(NBWL)

wl[:len(wl0)]=wl0[:]
tr[:len(tr0)]=tr0[:]

# %%
tel_mt=Telescope()
# Out:
# **** Throughputs.__init__****
# System loaded from /cvmfs/sw.lsst.eu/linux-x86_64/lsst_sims/sims_2_10_0/stack/miniconda3-4.5.4-fcd27eb/Linux64/throughputs/2017.01.31-6-g29ce4f5/baseline/
# **** Telescope.__init__******

# %%
tel_mt.Set_Atmosphere(am_mt,wl,tr)
tel_mt.Plot_Throughputs()

# %% [markdown]
# ## Tune Airmass in LibRadTran

# %%
all_airmass_rt=np.arange(1.,2.2,0.025)

# %%
NBRTFILES=len(all_airmass_rt)

# %%
NBSED_SEL=5000

# %% [markdown]
# # Simulate LibRadTran

# %% [markdown]
# ## Default config

# %%
pressure = 782.5
pwv=4.86
aer=0
ozone=341.
wl0=500.

# %%
all_rtdata=[]
for am in all_airmass_rt:
    path,thefile=rt.ProcessSimulationaer(am,pwv,ozone,wl0,aer)
    #path,thefile=rt.ProcessSimulation(am,pwv,ozone)
    data = np.loadtxt(os.path.join(path,thefile))
    all_rtdata.append(data)
# Out:
# --------------------------------------------
#  1) airmass =  1.0
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z10_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z10_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z10_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z10_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.025
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z10_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z10_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z10_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z10_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.0499999999999998
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z10_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z10_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z10_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z10_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.0749999999999997
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z10_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z10_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z10_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z10_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.0999999999999996
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z10_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z10_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z10_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z10_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.1249999999999996
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z11_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z11_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z11_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z11_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.1499999999999995
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z11_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z11_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z11_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z11_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.1749999999999994
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z11_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z11_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z11_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z11_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.1999999999999993
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z11_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z11_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z11_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z11_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.2249999999999992
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z12_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z12_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z12_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z12_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.2499999999999991
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z12_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z12_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z12_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z12_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.274999999999999
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z12_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z12_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z12_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z12_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.299999999999999
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z12_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z12_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z12_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z12_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.3249999999999988
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z13_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z13_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z13_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z13_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.3499999999999988
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z13_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z13_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z13_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z13_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.3749999999999987
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z13_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z13_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z13_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z13_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.3999999999999986
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z13_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z13_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z13_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z13_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.4249999999999985
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z14_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z14_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z14_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z14_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.4499999999999984
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z14_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z14_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z14_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z14_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.4749999999999983
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z14_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z14_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z14_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z14_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.4999999999999982
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z14_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z14_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z14_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z14_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.5249999999999981
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z15_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z15_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z15_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z15_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.549999999999998
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z15_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z15_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z15_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z15_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.574999999999998
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z15_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z15_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z15_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z15_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.5999999999999979
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z15_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z15_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z15_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z15_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.6249999999999978
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z16_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z16_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z16_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z16_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.6499999999999977
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z16_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z16_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z16_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z16_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.6749999999999976
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z16_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z16_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z16_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z16_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.6999999999999975
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z16_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z16_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z16_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z16_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.7249999999999974
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z17_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z17_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z17_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z17_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.7499999999999973
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z17_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z17_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z17_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z17_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.7749999999999972
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z17_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z17_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z17_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z17_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.7999999999999972
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z17_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z17_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z17_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z17_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.824999999999997
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z18_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z18_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z18_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z18_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.849999999999997
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z18_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z18_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z18_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z18_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.874999999999997
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z18_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z18_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z18_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z18_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.8999999999999968
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z18_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z18_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z18_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z18_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.9249999999999967
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z19_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z19_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z19_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z19_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.9499999999999966
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z19_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z19_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z19_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z19_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.9749999999999965
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z19_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z19_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z19_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z19_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  1.9999999999999964
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z19_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z19_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z19_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z19_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  2.0249999999999964
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z20_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z20_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z20_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z20_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  2.0499999999999963
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z20_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z20_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z20_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z20_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  2.074999999999996
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z20_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z20_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z20_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z20_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  2.099999999999996
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z20_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z20_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z20_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z20_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  2.124999999999996
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z21_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z21_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z21_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z21_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  2.149999999999996
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z21_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z21_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z21_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z21_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  2.174999999999996
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z21_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z21_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z21_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z21_wv48_oz34_aer0.OUT
# --------------------------------------------
#  1) airmass =  2.1999999999999957
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z21_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z21_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z21_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z21_wv48_oz34_aer0.OUT

# %%
jet = cm = plt.get_cmap('jet')
cNorm  = colors.Normalize(vmin=0, vmax=NBRTFILES)
scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=jet)

# %%
for idx in np.arange(NBRTFILES):    
    colorVal = scalarMap.to_rgba(idx)
    thelabel="am={:2.1f}".format(all_airmass_rt[idx])
    plt.plot(all_rtdata[idx][:,0],all_rtdata[idx][:,1],color=colorVal,label=thelabel)
plt.grid(True)
plt.title("LIBRADTRAN airmass scan")
plt.xlabel("$\lambda$ (nm)")
plt.ylabel("atmospheric transparency")
plt.legend(loc='upper left')

# %% [markdown]
# # LibRadTran Telescope

# %%
all_airmass_rt
# Out:
# array([1.   , 1.025, 1.05 , 1.075, 1.1  , 1.125, 1.15 , 1.175, 1.2  ,
#        1.225, 1.25 , 1.275, 1.3  , 1.325, 1.35 , 1.375, 1.4  , 1.425,
#        1.45 , 1.475, 1.5  , 1.525, 1.55 , 1.575, 1.6  , 1.625, 1.65 ,
#        1.675, 1.7  , 1.725, 1.75 , 1.775, 1.8  , 1.825, 1.85 , 1.875,
#        1.9  , 1.925, 1.95 , 1.975, 2.   , 2.025, 2.05 , 2.075, 2.1  ,
#        2.125, 2.15 , 2.175, 2.2  ])

# %%
idx_am_sel=0

# %%
amsel=all_airmass_rt[idx_am_sel]

# %%
rtdata_sel=all_rtdata[idx_am_sel]

# %%
tel_rt=Telescope()
# Out:
# **** Throughputs.__init__****
# System loaded from /cvmfs/sw.lsst.eu/linux-x86_64/lsst_sims/sims_2_10_0/stack/miniconda3-4.5.4-fcd27eb/Linux64/throughputs/2017.01.31-6-g29ce4f5/baseline/
# **** Telescope.__init__******

# %%
tel_rt.Set_Atmosphere(amsel,rtdata_sel[:,0],rtdata_sel[:,1])
tel_rt.Plot_Throughputs()

# %% [markdown]
# # LOOP on SED

# %%
filter_tag='i'

# %%
def ComputeDeltaMagAndErrorMag(filter_tag,tel_rt,tel_mt,sed_data):
    
    
    filternum=all_filternum[filter_tag]-1
    skybrightness=LSST_SkyBrightness[filternum]
    FWHMgeom=LSST_GeomSeeing[filternum]
    
    
    # book collections
    all_pulls=np.zeros(NBSED_SEL)
    all_magdelta=np.zeros(NBSED_SEL)
    all_magerr=np.zeros(NBSED_SEL)

    #print("NBSED_SEL={}".format(NBSED_SEL))
    
    #loop on SED
    for idx_sed in np.arange(NBSED_SEL):
        # extract sed wl and flux
        picklesname='pickles_uvk_{}'.format(idx_sed+1)
        wl_sed=sed_data[0,sidx_spec:]/10.
        flux_sed=sed_data[idx_sed+1,sidx_spec:]*10.
        
        # fill Telescope with that SED
        tel_rt.Set_SED(wavel=wl_sed,newsed=flux_sed,name=picklesname)
        tel_mt.Set_SED(wavel=wl_sed,newsed=flux_sed,name=picklesname)
        
        #compute Instrumental Magnitude
        mag_adu_mt=tel_mt.CalcMyADUMagnitude_filter(filter_tag)
        mag_adu_rt=tel_rt.CalcMyADUMagnitude_filter(filter_tag)
        
        # compute magnitude error and delta mag
        mag_error=tel_rt.CalcMyABMagnitudesError_filter(filter_tag,skybrightness,FWHMgeom)
        delta_mag= mag_adu_mt-mag_adu_rt
    
        #print('\Delta M = {} \delta m = {} '.format(delta_mag,mag_error))
        
        #fill collection
        all_pulls[idx_sed]=delta_mag/mag_error
        all_magdelta[idx_sed]=delta_mag
        all_magerr[idx_sed]=mag_error
        
        
        #plt.semilogy(wl_sed,flux_sed)

    return all_magdelta,all_magerr,all_pulls

# %%
def ComputeChi2(all_pulls):
    all_pulls2=all_pulls**2
    N=len(all_pulls)
    chi2=all_pulls2.sum()/(float(N-1))
    return chi2

# %% [markdown]
# # LOOP ON airmass in LibRadTran

# %%
jet = cm = plt.get_cmap('jet')
cNorm  = colors.Normalize(vmin=all_airmass_rt.min(), vmax=all_airmass_rt.max())
scalarMap = cmx.ScalarMappable(norm=cNorm, cmap=jet)
all_colorvalues    = [scalarMap.to_rgba(theam) for theam in all_airmass_rt]
scalarMap.set_array(all_colorvalues)

# %%
all_chi2=[]

plt.figure()
for idx,theam in np.ndenumerate(all_airmass_rt):
    print("index_am={} , z={}".format(idx[0],theam))
    
    
    # select atmosphere for libradtran
    idx_pwv_sel=idx[0]
    rtdata_sel=all_rtdata[idx_pwv_sel]
    tel_rt.Set_Atmosphere(am,rtdata_sel[:,0],rtdata_sel[:,1])
    all_magdelta,all_magerr,all_pulls=ComputeDeltaMagAndErrorMag(filter_tag,tel_rt,tel_mt,sed_data)
    all_chi2.append(ComputeChi2(all_pulls))
    
    
    colorVal = scalarMap.to_rgba(theam)
    thelabel="z={:2.1f} mm".format(theam)
    
    plt.hist(all_pulls,bins=100,range=(-0.2,0.2),color=colorVal,alpha=0.8);
    
cbar=plt.colorbar(scalarMap)
cbar.set_label('am', rotation=270)    
    
plt.grid(True)
plt.xlabel("pull",fontweight='bold',fontsize=20)
title="Pulls Distribution pull$\equiv(M_{mt}^I-M_{rt}^I)/\sigma_M$"
title=title+" for airmass scan"
plt.title(title,fontweight='bold',fontsize=25)
#plt.legend(loc='best')
# Out:
# index_am=0 , z=1.0
# index_am=1 , z=1.025
# index_am=2 , z=1.0499999999999998
# index_am=3 , z=1.0749999999999997
# index_am=4 , z=1.0999999999999996
# index_am=5 , z=1.1249999999999996
# index_am=6 , z=1.1499999999999995
# index_am=7 , z=1.1749999999999994
# index_am=8 , z=1.1999999999999993
# index_am=9 , z=1.2249999999999992
# index_am=10 , z=1.2499999999999991
# index_am=11 , z=1.274999999999999
# index_am=12 , z=1.299999999999999
# index_am=13 , z=1.3249999999999988
# index_am=14 , z=1.3499999999999988
# index_am=15 , z=1.3749999999999987
# index_am=16 , z=1.3999999999999986
# index_am=17 , z=1.4249999999999985
# index_am=18 , z=1.4499999999999984
# index_am=19 , z=1.4749999999999983
# index_am=20 , z=1.4999999999999982
# index_am=21 , z=1.5249999999999981
# index_am=22 , z=1.549999999999998
# index_am=23 , z=1.574999999999998
# index_am=24 , z=1.5999999999999979
# index_am=25 , z=1.6249999999999978
# index_am=26 , z=1.6499999999999977
# index_am=27 , z=1.6749999999999976
# index_am=28 , z=1.6999999999999975
# index_am=29 , z=1.7249999999999974
# index_am=30 , z=1.7499999999999973
# index_am=31 , z=1.7749999999999972
# index_am=32 , z=1.7999999999999972
# index_am=33 , z=1.824999999999997
# index_am=34 , z=1.849999999999997
# index_am=35 , z=1.874999999999997
# index_am=36 , z=1.8999999999999968
# index_am=37 , z=1.9249999999999967
# index_am=38 , z=1.9499999999999966
# index_am=39 , z=1.9749999999999965
# index_am=40 , z=1.9999999999999964
# index_am=41 , z=2.0249999999999964
# index_am=42 , z=2.0499999999999963
# index_am=43 , z=2.074999999999996
# index_am=44 , z=2.099999999999996
# index_am=45 , z=2.124999999999996
# index_am=46 , z=2.149999999999996
# index_am=47 , z=2.174999999999996
# index_am=48 , z=2.1999999999999957
# Text(0.5,1,'Pulls Distribution pull$\\equiv(M_{mt}^I-M_{rt}^I)/\\sigma_M$ for airmass scan')

# %% [markdown]
# # Estimation of optimal airmass in libradtran

# %%
x=np.array(all_airmass_rt)
y=np.array(all_chi2)
z = np.polyfit(x, y, 4)
parab= np.poly1d(z)
newx=np.linspace(x[0],x[-1],50)
newy=parab(newx)

# %%
title="$\chi^2/(N-1)$ vs pwv for $\Delta M^I=M_{mt}^I-M_{rt}^I$"
title=title+" for airmass scan"
plt.plot(all_airmass_rt,all_chi2,'bo',label='data')
plt.plot(newx,newy,'r:',label='fit')
plt.ylabel("$\chi^2/(N-1)$",fontweight='bold',fontsize=20)
plt.xlabel("airmass (rt)",fontweight='bold',fontsize=20)
plt.grid(True)
plt.title(title,fontweight='bold',fontsize=25)
plt.legend(loc="upper right")

# %%
z
# Out:
# array([   1.13438001,  -11.15827302,   62.05669687, -154.17861328,
#         131.38790881])

# %%
def FindOptimum(X,Y):
    idx0=np.where(Y==Y.min())[0][0]
    print("minimum is at X={}, Y={}".format(X[idx0],Y[idx0]))
    
    close_idx=np.where(Y<=Y.min()+1)[0]
    #for idx2 in close_idx:
    #      print("neighbourg {} : is at X={}, Y={}".format(idx2,X[idx2],Y[idx2]))
            
    print("X1 = {} - X2 = {}".format(X[close_idx[0]], X[close_idx[-1]]))
    sigma=0.5*( (X[idx0]-X[close_idx[0]])+(X[close_idx[-1]]-X[idx0]))
    print("Sigma= {}".format(sigma))
    return X[idx0],sigma

# %%
amz0,sig_amz0=FindOptimum(newx,newy)
# Out:
# minimum is at X=2.0775510204081593, Y=-0.0006346003440853565
# X1 = 1.8816326530612213 - X2 = 2.1999999999999957
# Sigma= 0.15918367346938722

# %% [markdown]
# # Find Magnitude difference

# %%
path,thefile=rt.ProcessSimulationaer(amz0,pwv,ozone,wl0,aer)
#path,thefile=rt.ProcessSimulation(am,pwv,ozone)
rtdata0 = np.loadtxt(os.path.join(path,thefile))
# Out:
# --------------------------------------------
#  1) airmass =  2.0775510204081593
#  2) pwv =  4.86
#  3) oz =  341.0
#  4) wl0 =  500.0
#  5) tau0 =  0
# --------------------------------------------
# Running uvspec with input file:  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z20_wv48_oz34_aer0.INP
# Output to file                :  /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z20_wv48_oz34_aer0.OUT
# uvspec cmd:  /pbs/throng/lsst/users/dagoret/External/libRadtran/libRadtran-2.0.1/bin/uvspec  < /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/in/RT_LS_pp_us_sa_rt_z20_wv48_oz34_aer0.INP > /scratch/dagoret/simulations/RT/2.0.1/LS/pp/us/sa/rt/out/RT_LS_pp_us_sa_rt_z20_wv48_oz34_aer0.OUT

# %%
tel_rt.Set_Atmosphere(am,rtdata0[:,0],rtdata0[:,1])

# %%
#tel_rt.Plot_Throughputs()

# %%
all_magdelta0,all_magerr0,all_pulls0=ComputeDeltaMagAndErrorMag(filter_tag,tel_rt,tel_mt,sed_data)

# %%
mag_mean=all_magdelta0.mean()
mag_std=all_magdelta0.std()

# %%
plt.hist(all_magdelta0,bins=50,range=(-0.011,0.011),color="blue");
plt.grid()

xlabel="$\Delta M$ (= {:6.5f} +/- {:6.5f} mag)".format(mag_mean,mag_std)
plt.xlabel(xlabel,fontweight='bold',fontsize=25)
title="Magnitude difference in {} filter for z_mt={:3.2f}, z_rt={:3.2f} mm".format(filter_tag,am_mt,amz0)
plt.title(title,fontweight='bold',fontsize=25)
# Out:
# Text(0.5,1,'Magnitude difference in i filter for z_mt=2.00, z_rt=2.08 mm')
